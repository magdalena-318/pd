# %% [markdown]
# <a href="https://colab.research.google.com/github/magdalena-318/pd/blob/main/szczepaniak_magdalena_1_numerZajec_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
main = pd.read_csv("/content/test.csv")

# %%
df_titanic = main.copy()

# %%
df_titanic = df_titanic[["Name","Age","Sex"]]

# %%
df_titanic
# Out:
#                                              Name   Age     Sex
# 0                                Kelly, Mr. James  34.5    male
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                       Myles, Mr. Thomas Francis  62.0    male
# 3                                Wirz, Mr. Albert  27.0    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# ..                                            ...   ...     ...
# 413                            Spector, Mr. Woolf   NaN    male
# 414                  Oliva y Ocana, Dona. Fermina  39.0  female
# 415                  Saether, Mr. Simon Sivertsen  38.5    male
# 416                           Ware, Mr. Frederick   NaN    male
# 417                      Peter, Master. Michael J   NaN    male
#
# [418 rows x 3 columns]

# %%
df_titanic.describe()
# Out:
#               Age
# count  332.000000
# mean    30.272590
# std     14.181209
# min      0.170000
# 25%     21.000000
# 50%     27.000000
# 75%     39.000000
# max     76.000000

# %%
# czyli mediana to 27

# %%
df_titanic['Sex'] = df_titanic['Sex'].map({'male' : 0, 'female' : 1})

# %%
df_titanic
# Out:
#                                              Name   Age  Sex
# 0                                Kelly, Mr. James  34.5    0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0    1
# 2                       Myles, Mr. Thomas Francis  62.0    0
# 3                                Wirz, Mr. Albert  27.0    0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0    1
# ..                                            ...   ...  ...
# 413                            Spector, Mr. Woolf   NaN    0
# 414                  Oliva y Ocana, Dona. Fermina  39.0    1
# 415                  Saether, Mr. Simon Sivertsen  38.5    0
# 416                           Ware, Mr. Frederick   NaN    0
# 417                      Peter, Master. Michael J   NaN    0
#
# [418 rows x 3 columns]

# %%
men = (df_titanic['Sex'] == 0).sum()
women = (df_titanic['Sex'] == 1).sum()

# %%
print("Liczba mężczyzn: ", men)
print("Liczba kobiet: ", women)
# Out:
# Liczba mężczyzn:  266
# Liczba kobiet:  152

# %%
import numpy as np

# %%
df_titanic['Year of birth'] = np.floor(1912 - df_titanic['Age'])

# %%
df_titanic
# Out:
#                                              Name   Age  Sex  Year of birth
# 0                                Kelly, Mr. James  34.5    0         1877.0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0    1         1865.0
# 2                       Myles, Mr. Thomas Francis  62.0    0         1850.0
# 3                                Wirz, Mr. Albert  27.0    0         1885.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0    1         1890.0
# ..                                            ...   ...  ...            ...
# 413                            Spector, Mr. Woolf   NaN    0            NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0    1         1873.0
# 415                  Saether, Mr. Simon Sivertsen  38.5    0         1873.0
# 416                           Ware, Mr. Frederick   NaN    0            NaN
# 417                      Peter, Master. Michael J   NaN    0            NaN
#
# [418 rows x 4 columns]
